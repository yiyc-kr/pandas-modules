# %%
import numpy as np
import pandas as pd

# %%
# Read csv
df = pd.read_csv("./data/test_raw_data.csv", dtype={"name": str, "code": str}, encoding="utf-8")
df
# Out:
#                                                 name      code
# 0                                      tools of wood      4417
# 1                                      broom of wood      4417
# 2                               brush bodies of wood      4417
# 3                                    handles of wood      4417
# 4                                tool bodies of wood      4417
# 5                               tool handles of wood      4417
# 6                                  hat-forms of felt      6501
# 7                                 hat bodies of felt      6501
# 8                                      hoods of felt      6501
# 9                                   manchons of felt      6501
# 10                                  plateaux of felt      6501
# 11                             slit manchons of felt      6501
# 12                                             beret  65010000
# 13                                      cap stuffing  65010000
# 14                                   cavalier's hats  65010000
# 15                                     felt hat body  65010000
# 16                                 felt hats preform  65010000
# 17                rabbit down felt semi-finished cap  65010000
# 18                                wool felt hat felt  65010000
# 19                       wool felt semi-finished cap  65010000
# 20                                wool fflt hat body  65010000
# 21       aluminium alloy outline border hollow glass  70052100
# 22                                arc double glazing  70052100
# 23                      big plate arc double glazing  70052100
# 24                          big plate double glazing  70052100
# 25                           body tinted float glass  70052100
# 26                          bulletproof hollow glass  70052100
# 27                               coated hollow glass  70052100
# 28                                color-glazed glass  70052100
# 29                              colored enamel glass  70052100
# ...                                              ...       ...
# 9999970                                 roller chain  73151190
# 9999971                     roller chain for farming  73151190
# 9999972                                roller chains  73151190
# 9999973                          roller sleeve chain  73151190
# 9999974                  roller transportation chain  73151190
# 9999975                             round link chain  73151190
# 9999976                             round-link chain  73151190
# 9999977                               cabinet handle  83024900
# 9999978                     camping travel tent pipe  83024900
# 9999979                                 candle stand  83024900
# 9999980                hardware craft glass fittings  83024900
# 9999981                          hardware decoration  83024900
# 9999982                             hardware erector  83024900
# 9999983                         rotational wall base  83024900
# 9999984           round pipe titanium umbrella frame  83024900
# 9999985                                curtain orbit  83024100
# 9999986                               curtain pelmet  83024100
# 9999987                                 curtain pipe  83024100
# 9999988                                 curtain pole  83024100
# 9999989                         curtain pole bracket  83024100
# 9999990                           staircase armguard  83024100
# 9999991                             staircase column  83024100
# 9999992                           staircase fittings  83024100
# 9999993                          staircase framework  83024100
# 9999994                           staircase handrail  83024100
# 9999995                               staircase pole  83024100
# 9999996                      aluminium material lamp  94054090
# 9999997                     aluminium pipe spotlight  94054090
# 9999998                          aluminium spotlight  94054090
# 9999999                          led light ornaments  94054090
#
# [10000000 rows x 2 columns]

# %%
# Select code
df2 = df.loc[(df["code"].str.len() > 5)].reset_index(drop=True)
df2
# Out:
#                                                 name      code
# 0                                              beret  65010000
# 1                                       cap stuffing  65010000
# 2                                    cavalier's hats  65010000
# 3                                      felt hat body  65010000
# 4                                  felt hats preform  65010000
# 5                 rabbit down felt semi-finished cap  65010000
# 6                                 wool felt hat felt  65010000
# 7                        wool felt semi-finished cap  65010000
# 8                                 wool fflt hat body  65010000
# 9        aluminium alloy outline border hollow glass  70052100
# 10                                arc double glazing  70052100
# 11                      big plate arc double glazing  70052100
# 12                          big plate double glazing  70052100
# 13                           body tinted float glass  70052100
# 14                          bulletproof hollow glass  70052100
# 15                               coated hollow glass  70052100
# 16                                color-glazed glass  70052100
# 17                              colored enamel glass  70052100
# 18                              aluminium alloy cage  76129010
# 19                aluminium easy-uncap two-piece can  76129010
# 20                             aluminium zip-top can  76129010
# 21                        aluminium zip-top can body  76129010
# 22                                      artistic tin  76129010
# 23                                      beverage can  76129010
# 24               big-opening easy-uncap aluminum can  76129010
# 25                                canister packaging  76129010
# 26                                 color printed can  76129010
# 27                                            flasks  76129010
# 28                          food and beverage bottle  76129010
# 29                          agricultural compartment  87079090
# ...                                              ...       ...
# 8792044                                 roller chain  73151190
# 8792045                     roller chain for farming  73151190
# 8792046                                roller chains  73151190
# 8792047                          roller sleeve chain  73151190
# 8792048                  roller transportation chain  73151190
# 8792049                             round link chain  73151190
# 8792050                             round-link chain  73151190
# 8792051                               cabinet handle  83024900
# 8792052                     camping travel tent pipe  83024900
# 8792053                                 candle stand  83024900
# 8792054                hardware craft glass fittings  83024900
# 8792055                          hardware decoration  83024900
# 8792056                             hardware erector  83024900
# 8792057                         rotational wall base  83024900
# 8792058           round pipe titanium umbrella frame  83024900
# 8792059                                curtain orbit  83024100
# 8792060                               curtain pelmet  83024100
# 8792061                                 curtain pipe  83024100
# 8792062                                 curtain pole  83024100
# 8792063                         curtain pole bracket  83024100
# 8792064                           staircase armguard  83024100
# 8792065                             staircase column  83024100
# 8792066                           staircase fittings  83024100
# 8792067                          staircase framework  83024100
# 8792068                           staircase handrail  83024100
# 8792069                               staircase pole  83024100
# 8792070                      aluminium material lamp  94054090
# 8792071                     aluminium pipe spotlight  94054090
# 8792072                          aluminium spotlight  94054090
# 8792073                          led light ornaments  94054090
#
# [8792074 rows x 2 columns]

# %%
# Update slice code
df2.code = df2.code.str.slice(stop=6)
df2
# Out:
#                                                 name    code
# 0                                              beret  650100
# 1                                       cap stuffing  650100
# 2                                    cavalier's hats  650100
# 3                                      felt hat body  650100
# 4                                  felt hats preform  650100
# 5                 rabbit down felt semi-finished cap  650100
# 6                                 wool felt hat felt  650100
# 7                        wool felt semi-finished cap  650100
# 8                                 wool fflt hat body  650100
# 9        aluminium alloy outline border hollow glass  700521
# 10                                arc double glazing  700521
# 11                      big plate arc double glazing  700521
# 12                          big plate double glazing  700521
# 13                           body tinted float glass  700521
# 14                          bulletproof hollow glass  700521
# 15                               coated hollow glass  700521
# 16                                color-glazed glass  700521
# 17                              colored enamel glass  700521
# 18                              aluminium alloy cage  761290
# 19                aluminium easy-uncap two-piece can  761290
# 20                             aluminium zip-top can  761290
# 21                        aluminium zip-top can body  761290
# 22                                      artistic tin  761290
# 23                                      beverage can  761290
# 24               big-opening easy-uncap aluminum can  761290
# 25                                canister packaging  761290
# 26                                 color printed can  761290
# 27                                            flasks  761290
# 28                          food and beverage bottle  761290
# 29                          agricultural compartment  870790
# ...                                              ...     ...
# 8792044                                 roller chain  731511
# 8792045                     roller chain for farming  731511
# 8792046                                roller chains  731511
# 8792047                          roller sleeve chain  731511
# 8792048                  roller transportation chain  731511
# 8792049                             round link chain  731511
# 8792050                             round-link chain  731511
# 8792051                               cabinet handle  830249
# 8792052                     camping travel tent pipe  830249
# 8792053                                 candle stand  830249
# 8792054                hardware craft glass fittings  830249
# 8792055                          hardware decoration  830249
# 8792056                             hardware erector  830249
# 8792057                         rotational wall base  830249
# 8792058           round pipe titanium umbrella frame  830249
# 8792059                                curtain orbit  830241
# 8792060                               curtain pelmet  830241
# 8792061                                 curtain pipe  830241
# 8792062                                 curtain pole  830241
# 8792063                         curtain pole bracket  830241
# 8792064                           staircase armguard  830241
# 8792065                             staircase column  830241
# 8792066                           staircase fittings  830241
# 8792067                          staircase framework  830241
# 8792068                           staircase handrail  830241
# 8792069                               staircase pole  830241
# 8792070                      aluminium material lamp  940540
# 8792071                     aluminium pipe spotlight  940540
# 8792072                          aluminium spotlight  940540
# 8792073                          led light ornaments  940540
#
# [8792074 rows x 2 columns]

# %%
# Replace name
df2.name = df2.name.str.replace(r"[.]{3}|[^a-zA-Z\- ]+", " ").str.replace(r"[\.\-]|\b([a-z]{1})\b", "", regex=True)\
                        .str.replace(r"[ ]{2,}", " ").str.strip()
df2
# Out:
#                                                 name    code
# 0                                              beret  650100
# 1                                       cap stuffing  650100
# 2                                      cavalier hats  650100
# 3                                      felt hat body  650100
# 4                                  felt hats preform  650100
# 5                  rabbit down felt semifinished cap  650100
# 6                                 wool felt hat felt  650100
# 7                         wool felt semifinished cap  650100
# 8                                 wool fflt hat body  650100
# 9        aluminium alloy outline border hollow glass  700521
# 10                                arc double glazing  700521
# 11                      big plate arc double glazing  700521
# 12                          big plate double glazing  700521
# 13                           body tinted float glass  700521
# 14                          bulletproof hollow glass  700521
# 15                               coated hollow glass  700521
# 16                                 colorglazed glass  700521
# 17                              colored enamel glass  700521
# 18                              aluminium alloy cage  761290
# 19                  aluminium easyuncap twopiece can  761290
# 20                              aluminium ziptop can  761290
# 21                         aluminium ziptop can body  761290
# 22                                      artistic tin  761290
# 23                                      beverage can  761290
# 24                 bigopening easyuncap aluminum can  761290
# 25                                canister packaging  761290
# 26                                 color printed can  761290
# 27                                            flasks  761290
# 28                          food and beverage bottle  761290
# 29                          agricultural compartment  870790
# ...                                              ...     ...
# 8792044                                 roller chain  731511
# 8792045                     roller chain for farming  731511
# 8792046                                roller chains  731511
# 8792047                          roller sleeve chain  731511
# 8792048                  roller transportation chain  731511
# 8792049                             round link chain  731511
# 8792050                              roundlink chain  731511
# 8792051                               cabinet handle  830249
# 8792052                     camping travel tent pipe  830249
# 8792053                                 candle stand  830249
# 8792054                hardware craft glass fittings  830249
# 8792055                          hardware decoration  830249
# 8792056                             hardware erector  830249
# 8792057                         rotational wall base  830249
# 8792058           round pipe titanium umbrella frame  830249
# 8792059                                curtain orbit  830241
# 8792060                               curtain pelmet  830241
# 8792061                                 curtain pipe  830241
# 8792062                                 curtain pole  830241
# 8792063                         curtain pole bracket  830241
# 8792064                           staircase armguard  830241
# 8792065                             staircase column  830241
# 8792066                           staircase fittings  830241
# 8792067                          staircase framework  830241
# 8792068                           staircase handrail  830241
# 8792069                               staircase pole  830241
# 8792070                      aluminium material lamp  940540
# 8792071                     aluminium pipe spotlight  940540
# 8792072                          aluminium spotlight  940540
# 8792073                          led light ornaments  940540
#
# [8792074 rows x 2 columns]

# %%
# Drop white space name
df2 = df2[(df2.name != '') & (df2.name != ' ')].reset_index(drop=True)
df2
# Out:
#                                                 name    code
# 0                                              beret  650100
# 1                                       cap stuffing  650100
# 2                                      cavalier hats  650100
# 3                                      felt hat body  650100
# 4                                  felt hats preform  650100
# 5                  rabbit down felt semifinished cap  650100
# 6                                 wool felt hat felt  650100
# 7                         wool felt semifinished cap  650100
# 8                                 wool fflt hat body  650100
# 9        aluminium alloy outline border hollow glass  700521
# 10                                arc double glazing  700521
# 11                      big plate arc double glazing  700521
# 12                          big plate double glazing  700521
# 13                           body tinted float glass  700521
# 14                          bulletproof hollow glass  700521
# 15                               coated hollow glass  700521
# 16                                 colorglazed glass  700521
# 17                              colored enamel glass  700521
# 18                              aluminium alloy cage  761290
# 19                  aluminium easyuncap twopiece can  761290
# 20                              aluminium ziptop can  761290
# 21                         aluminium ziptop can body  761290
# 22                                      artistic tin  761290
# 23                                      beverage can  761290
# 24                 bigopening easyuncap aluminum can  761290
# 25                                canister packaging  761290
# 26                                 color printed can  761290
# 27                                            flasks  761290
# 28                          food and beverage bottle  761290
# 29                          agricultural compartment  870790
# ...                                              ...     ...
# 8791567                                 roller chain  731511
# 8791568                     roller chain for farming  731511
# 8791569                                roller chains  731511
# 8791570                          roller sleeve chain  731511
# 8791571                  roller transportation chain  731511
# 8791572                             round link chain  731511
# 8791573                              roundlink chain  731511
# 8791574                               cabinet handle  830249
# 8791575                     camping travel tent pipe  830249
# 8791576                                 candle stand  830249
# 8791577                hardware craft glass fittings  830249
# 8791578                          hardware decoration  830249
# 8791579                             hardware erector  830249
# 8791580                         rotational wall base  830249
# 8791581           round pipe titanium umbrella frame  830249
# 8791582                                curtain orbit  830241
# 8791583                               curtain pelmet  830241
# 8791584                                 curtain pipe  830241
# 8791585                                 curtain pole  830241
# 8791586                         curtain pole bracket  830241
# 8791587                           staircase armguard  830241
# 8791588                             staircase column  830241
# 8791589                           staircase fittings  830241
# 8791590                          staircase framework  830241
# 8791591                           staircase handrail  830241
# 8791592                               staircase pole  830241
# 8791593                      aluminium material lamp  940540
# 8791594                     aluminium pipe spotlight  940540
# 8791595                          aluminium spotlight  940540
# 8791596                          led light ornaments  940540
#
# [8791597 rows x 2 columns]

# %%
# Count duplicated data about name with code
df2 = df2.groupby(["name", "code"]).agg('size').reset_index(name="counts")
# df2 = df2.groupby(["name", "code"]).size().reset_index(name="counts")
df2
# Out:
#                                              name    code  counts
# 0                             aa alkaline battery  850610      10
# 1                                        aa brace  730890      16
# 2                                      aa bracket  730890      14
# 3                            aa fresh royal jelly  410004      13
# 4                         aa superenergy adhesive  350691       9
# 5                            aaa alkaline battery  850610      11
# 6                                             aac  761490      47
# 7                                             aac  854442      12
# 8                                             aac  854449      55
# 9              aaluminium side window for vehicle  870829      16
# 10                                aanimal agentia  300490       4
# 11                                    ab adhesive  350691      37
# 12                             ab approach switch  853650      40
# 13                                        ab bond  350691       8
# 14                      ab double tile paperboard  480810      23
# 15                                     ab ebonite  350691      24
# 16                               ab foam material  392113      57
# 17                                        ab glue  350691     132
# 18                                        ab glue  350699      34
# 19                                      ab tubing  392690      25
# 20                                       ab water  390950      52
# 21                               ab water diamond  701810      55
# 22                                        ab yarn  540269      26
# 23                                         abacus  901720      12
# 24                                   abacus frame  950300       7
# 25                                   abalone bowl  701399      47
# 26                     abalone breeding implement  392690      11
# 27                          abalone compound feed  230990       6
# 28                           abalone cooking cart  871680      16
# 29                       abalone cooking pushcart  871680      17
# ...                                           ...     ...     ...
# 439431                                 zorror hat  950590       4
# 439432                    zorubicin hydrochloride  294190      14
# 439433                               zouma thread  540110      12
# 439434                            zp power module  851770       1
# 439435                               zu shuang ye  380894      28
# 439436                                     zu tie  330790      24
# 439437                         zuanxin lotus seed  121299       4
# 439438                        zuanxin xiang lotus  121299       4
# 439439  zubeining spraying agent for foot disease  330790      16
# 439440                    zubikang spraying agent  330790      12
# 439441                         zublin simplex bit  820750       2
# 439442                              zudai chicken  105949      13
# 439443              zudai luoman brownegg chicken  105941      80
# 439444                              zudai poulard  105941      80
# 439445                       zui xiao xie crablat  160510      25
# 439446                             zuiluohan wine  220890       2
# 439447                               zuiqianzhang  200190      16
# 439448                   zuixian wenchang chicken  160232       3
# 439449                         zuixiang green tea  902109       2
# 439450                             zujiao machine  846599       8
# 439451                          zulong snake wine  220890       2
# 439452                         zulong techun wine  220890       2
# 439453                 zun type radio alarm clock  852792       1
# 439454                       zuocan partner honey  410009      41
# 439455                                 zuoji flax  540761       2
# 439456                     zuozema polyester silk  540771       5
# 439457             zwitterion type polyacrylamide  390690       9
# 439458                     zyme extraction enzyme  350790      10
# 439459                                     zymine  350790      10
# 439460          zzl series winding vacuum coaters  854330      15
#
# [439461 rows x 3 columns]

# %%
# Extract max count row
df2 = df2.iloc[df2.groupby("name")["counts"].idxmax()]
df2
# Out:
#                                              name    code  counts
# 0                             aa alkaline battery  850610      10
# 1                                        aa brace  730890      16
# 2                                      aa bracket  730890      14
# 3                            aa fresh royal jelly  410004      13
# 4                         aa superenergy adhesive  350691       9
# 5                            aaa alkaline battery  850610      11
# 8                                             aac  854449      55
# 9              aaluminium side window for vehicle  870829      16
# 10                                aanimal agentia  300490       4
# 11                                    ab adhesive  350691      37
# 12                             ab approach switch  853650      40
# 13                                        ab bond  350691       8
# 14                      ab double tile paperboard  480810      23
# 15                                     ab ebonite  350691      24
# 16                               ab foam material  392113      57
# 17                                        ab glue  350691     132
# 19                                      ab tubing  392690      25
# 20                                       ab water  390950      52
# 21                               ab water diamond  701810      55
# 22                                        ab yarn  540269      26
# 23                                         abacus  901720      12
# 24                                   abacus frame  950300       7
# 25                                   abalone bowl  701399      47
# 26                     abalone breeding implement  392690      11
# 27                          abalone compound feed  230990       6
# 28                           abalone cooking cart  871680      16
# 29                       abalone cooking pushcart  871680      17
# 30                                   abalone feed  230990       6
# 31                                    abalone fry  301991      34
# 32                                  abalone juice  210390      40
# ...                                           ...     ...     ...
# 439431                                 zorror hat  950590       4
# 439432                    zorubicin hydrochloride  294190      14
# 439433                               zouma thread  540110      12
# 439434                            zp power module  851770       1
# 439435                               zu shuang ye  380894      28
# 439436                                     zu tie  330790      24
# 439437                         zuanxin lotus seed  121299       4
# 439438                        zuanxin xiang lotus  121299       4
# 439439  zubeining spraying agent for foot disease  330790      16
# 439440                    zubikang spraying agent  330790      12
# 439441                         zublin simplex bit  820750       2
# 439442                              zudai chicken  105949      13
# 439443              zudai luoman brownegg chicken  105941      80
# 439444                              zudai poulard  105941      80
# 439445                       zui xiao xie crablat  160510      25
# 439446                             zuiluohan wine  220890       2
# 439447                               zuiqianzhang  200190      16
# 439448                   zuixian wenchang chicken  160232       3
# 439449                         zuixiang green tea  902109       2
# 439450                             zujiao machine  846599       8
# 439451                          zulong snake wine  220890       2
# 439452                         zulong techun wine  220890       2
# 439453                 zun type radio alarm clock  852792       1
# 439454                       zuocan partner honey  410009      41
# 439455                                 zuoji flax  540761       2
# 439456                     zuozema polyester silk  540771       5
# 439457             zwitterion type polyacrylamide  390690       9
# 439458                     zyme extraction enzyme  350790      10
# 439459                                     zymine  350790      10
# 439460          zzl series winding vacuum coaters  854330      15
#
# [400419 rows x 3 columns]

# %%
# Seperate and make train, test dataframes
from sklearn.model_selection import train_test_split
train, test = train_test_split(df2, test_size=0.2)

# %%
train
# Out:
#                                                      name    code  counts
# 94252                                cotton nitrilon yarn  540239      11
# 353675                                 sheet pulp machine  844140       7
# 242208                              magic spotted granite  680293      12
# 299469                                 plastic barricades  392690       4
# 396192                         telecommunication fittings  851770     115
# 196192  highefficiency energysaving silicon carbide ba...  690390      24
# 40468                                    biochemical tube  701790      19
# 35216                                           bath ball  392111     122
# 50631                                     bulrush curtain  460129      65
# 166961            fullclosed maintenancefree battery case  850790      13
# 201081                           hose tubedrawing machine  847740      12
# 274622                 nonferrous strip plate rollig mill  845521      24
# 231724                                        leda lotion  300490      12
# 225315                                         lady shoes  640199      34
# 321942                  pure aluminium selfplugging rivet  761610       6
# 221872                        kanamycin sulfate injection  294190      17
# 138850                        european style inlaid glass  701610      26
# 298318                                          pizza pot  732393      17
# 202934                                 household hardware  820320      42
# 413637          uhf band professional wireless microphone  851810       3
# 16074                                      antenna sharer  847330      38
# 277971                                   oblique row nail  731700      12
# 131781                electronic semisteel collection box  830300       1
# 244680                                   manhole cylinder  732510      42
# 278752     oil carrying type mould temperature controller  847780       3
# 241800                                    machinery parts  847990      44
# 390347         super critical extraction seabuckthorn oil  330129      45
# 359985                               single lamp inverter  850440       1
# 85413                      computer exam certificate card  482110      11
# 374479                                        sport wheel  830220      24
# ...                                                   ...     ...     ...
# 174668                          glass fiber checked plaid  701959       7
# 358043                                          silk core  940490      55
# 437613                             yarndyed elastic cloth  520849     103
# 102048                                       data display  853120      39
# 350114                             selftapping wall screw  731814       2
# 148815                                          fish cake  160420      11
# 172799                                 germanite mattress  940429       4
# 234663                                    line gap filter  842129      16
# 61409                                        ceiling tile  680299       6
# 159955                foursquare electric display cabinet  940389       7
# 100323                            cutting machinery mould  848049      15
# 400067                                      thread device  820559       4
# 207093  imitation ancient bamboo joint thin silk face fan  482390      42
# 416689                          usstyle hand crank window  730830      22
# 119304                             drilling machine clamp  846620       2
# 83817                       compound amino acid injection  300490       4
# 322663             pure natural wild chrysanthemum flower  121190      16
# 143920                         feed for freshwater shrimp  230990      14
# 160729                                        free roller  843139      13
# 21727                             assembling traction pin  871690       4
# 401770              threespar dual column hydraulic press  841229       4
# 98632                                   crystal spotlight  940540       4
# 41801                         black square head ring lock  830140      26
# 298636                                       plane button  830810       8
# 350871                                  semifinished gear  732599      30
# 218909            ironsiliconaluminium type magnetic core  850490      22
# 16777                     antifebrile lung clearing syrup  300490      16
# 180716                         ground push chain conveyor  842839       2
# 281482                    open type oil fuel small boiler  840310      10
# 332164     reducer for environmental protection equipment  848340       4
#
# [320335 rows x 3 columns]

# %%
test
# Out:
#                                                      name    code  counts
# 205928                    hypersensitivity metal detector  854370       3
# 331900                     red rosewood whole set cabinet  940360      11
# 40229                              bimetallic thermometer  902519      32
# 352014                                  settop box sharer  847141      36
# 412669                                   twolamp uv drier  841939      14
# 315613                            precision smelting tool  846610      44
# 219776                      jacquard maillot without sash  610990     101
# 203085                          household quick sharpener  850980       6
# 101561                                    dairy food film  392099      39
# 2067                               acidity deoiling agent  340290       7
# 277403                                       nylon oxford  540710      27
# 132684                      electrostatic spraying device  842489      12
# 30598                                   backblock shelves  730890       5
# 344242                              salt and fog test box  903120       9
# 104390         delivery center management system software  980300       4
# 294627                                  petroleum asphalt  271320      63
# 61309                                        ceiling disk  940599       2
# 343624                                     saddle leather  392113       9
# 94325                                       cotton poplin  521011      82
# 308317                           polyester taffeta lining  540742      13
# 13024   aluminum alloy profiles of safety pushingdrawi...  761090       6
# 386391                                              stool  940210      47
# 217897                                     iron door bolt  830241       3
# 174107                       glass basin bathroom cabinet  940389       9
# 415477                           universal ratchet wrench  820412       6
# 269450                                   nailpolish brush  960329       6
# 115351                                    double side eva  392119      29
# 43967                                    boiled cane shot  200510      48
# 89627                           controllable oneway valve  848130      15
# 169996                                      gas appliance  732111       6
# ...                                                   ...     ...     ...
# 253440                                       metallic tin  800110      19
# 134004                   emergency light leadacid battery  850720      12
# 183334                                   hand fishing rod  950710       8
# 343208                   rubberplastic soft lamina sander  846593      19
# 217517                           iron art resin droplight  940510      10
# 117498                 doublesided nonwoven adhesive tape  590610       1
# 343940                  safety protection rail fence plug  730729      28
# 119387                             drinking water machine  851679       3
# 149854                                     fiveway switch  853650       1
# 138164                erythromycin ethylsuccinate tablets  300490       3
# 57856                                        carpet brush  960390      27
# 386890                                straight hair cream  330590      31
# 170777                                gasliquid separator  841989      16
# 351259                                         sensitizer  370710      18
# 193603                     high resolution digital camera  852580       3
# 113683                      double airchamber branch pump  871690      18
# 22826                     auto distributing adhesive tape  391910      29
# 232024                              leisure tent umbrella  660199       7
# 74187                            co firefighting cylinder  731100       6
# 390646                 super strong decontamination water  340220      13
# 258657                                    minitype server  847141      61
# 92728                                         corn ketone  294200      26
# 280318            oily conventional type lightening agent  340510      12
# 407135                 transfer decolouring shaking table  847982       7
# 221283                                   jinqian mushroom  709599      36
# 429264         white horn micro carving gold fountain pen  960820       5
# 172840   germantype worm wheel and worm larynxshaped hoop  730792      28
# 364235              slow releasing sterilization algicide  380892      19
# 268379                                multipurpose shovel  820130      20
# 271985         network communication product for computer  851762       1
#
# [80084 rows x 3 columns]

# %%
# Extract dataframe to csv
train.to_csv("./data/train_file.txt", sep='\t', encoding='utf-8', header=False, index=False, columns=["name", "code"])
test.to_csv("./data/test_file.txt", sep='\t', encoding='utf-8', header=False, index=False, columns=["name", "code"])

# %% [markdown]
# ## Saving

# %%
# Delete one column and save
'''
df = pd.read_csv("./data/test_raw_data.csv")
df = df.drop(["Unnamed: 0"], axis=1)
df.to_csv("./data/test_raw_data.csv", index=False)
'''
# Out:
# '\ndf = pd.read_csv("./data/test_raw_data.csv")\ndf = df.drop(["Unnamed: 0"], axis=1)\ndf.to_csv("./data/test_raw_data.csv", index=False)\n'

# %%
# For test
# df2.loc[df2["name"].str.contains("dioxyanth", na=False)]
# Out:
#                            name    code
# 349314   1-2-dioxyanthraquinone  291469
# 1365317      dioxyanthraquinone  294200
# 2085845      dioxyanthraquinone  294200
# 3921937  1-2-dioxyanthraquinone  291469
# 6721377  1-2-dioxyanthraquinone  291469
# 7473146      dioxyanthraquinone  294200
# 8635622  1-2-dioxyanthraquinone  291469

# %%
# PREP lambda
df2 = df2.groupby(["name", "code"]).agg({"counts": "sum"})
df2
# Out:
#                                                   counts
# name                                      code
# aa alkaline battery                       850610      10
# aa brace                                  730890      16
# aa bracket                                730890      14
# aa fresh royal jelly                      410004      13
# aa superenergy adhesive                   350691       9
# aaa alkaline battery                      850610      11
# aac                                       761490      47
#                                           854442      12
#                                           854449      55
# aaluminium side window for vehicle        870829      16
# aanimal agentia                           300490       4
# ab adhesive                               350691      37
# ab approach switch                        853650      40
# ab bond                                   350691       8
# ab double tile paperboard                 480810      23
# ab ebonite                                350691      24
# ab foam material                          392113      57
# ab glue                                   350691     132
#                                           350699      34
# ab tubing                                 392690      25
# ab water                                  390950      52
# ab water diamond                          701810      55
# ab yarn                                   540269      26
# abacus                                    901720      12
# abacus frame                              950300       7
# abalone bowl                              701399      47
# abalone breeding implement                392690      11
# abalone compound feed                     230990       6
# abalone cooking cart                      871680      16
# abalone cooking pushcart                  871680      17
# ...                                                  ...
# zorror hat                                950590       4
# zorubicin hydrochloride                   294190      14
# zouma thread                              540110      12
# zp power module                           851770       1
# zu shuang ye                              380894      28
# zu tie                                    330790      24
# zuanxin lotus seed                        121299       4
# zuanxin xiang lotus                       121299       4
# zubeining spraying agent for foot disease 330790      16
# zubikang spraying agent                   330790      12
# zublin simplex bit                        820750       2
# zudai chicken                             105949      13
# zudai luoman brownegg chicken             105941      80
# zudai poulard                             105941      80
# zui xiao xie crablat                      160510      25
# zuiluohan wine                            220890       2
# zuiqianzhang                              200190      16
# zuixian wenchang chicken                  160232       3
# zuixiang green tea                        902109       2
# zujiao machine                            846599       8
# zulong snake wine                         220890       2
# zulong techun wine                        220890       2
# zun type radio alarm clock                852792       1
# zuocan partner honey                      410009      41
# zuoji flax                                540761       2
# zuozema polyester silk                    540771       5
# zwitterion type polyacrylamide            390690       9
# zyme extraction enzyme                    350790      10
# zymine                                    350790      10
# zzl series winding vacuum coaters         854330      15
#
# [439461 rows x 1 columns]

# %%
# Calcurate code percentage in same name
df2 = df2.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))

# %%
df2.index.name

# %%
# Show same name with different code
df2[df2.duplicated(["name"], keep=False)]
# Out:
#                                     name    code  counts
# 6                                    aac  761490      47
# 7                                    aac  854442      12
# 8                                    aac  854449      55
# 17                               ab glue  350691     132
# 18                               ab glue  350699      34
# 45                             abamectin  293399      23
# 46                             abamectin  380891      20
# 52                      abamectin powder  300420      49
# 53                      abamectin powder  300490      12
# 100                  abnormal elbow pipe  391740       6
# 101                  abnormal elbow pipe  730722      17
# 128         abnormal steel tube and pipe  730490      25
# 129         abnormal steel tube and pipe  730690       8
# 168                      abrading device  820559      24
# 169                      abrading device  850940      11
# 171                     abrasion machine  847910      22
# 172                     abrasion machine  902480       8
# 216                 abrasion wheel cover  732690      21
# 217                 abrasion wheel cover  846792      15
# 219                 abrasion wheel mould  680410      69
# 220                 abrasion wheel mould  848049      15
# 221                 abrasion wheel mould  848060      20
# 222                  abrasion wheel rack  730890      25
# 223                  abrasion wheel rack  940320      23
# 239            abrasionproof rubber ring  401693      13
# 240            abrasionproof rubber ring  401699      12
# 252           abrasionresistant pipeline  730650      13
# 253           abrasionresistant pipeline  730690      44
# 255                             abrasive  340600      13
# 256                             abrasive  680422      12
# ...                                  ...     ...     ...
# 439223                            zircon  710490      14
# 439244                     zirconia ball  261510      15
# 439245                     zirconia ball  690290       9
# 439254              zirconia ceramic rod  691490      12
# 439255              zirconia ceramic rod  854710       3
# 439257                 zirconia ceramics  690390       3
# 439258                 zirconia ceramics  691410      12
# 439259                 zirconia ceramics  691490      13
# 439266             zirconia ceramics rod  690911      26
# 439267             zirconia ceramics rod  854710       3
# 439281  zirconia oxygenquantity analyzer  902710      19
# 439282  zirconia oxygenquantity analyzer  902780      30
# 439303                    zirconium bead  282560      22
# 439304                    zirconium bead  810990      16
# 439306               zirconium carbonate  283699      16
# 439307               zirconium carbonate  284190      36
# 439317                 zirconium dioxide  261510      14
# 439318                 zirconium dioxide  282560      22
# 439332                   zirconium oxide  261510      14
# 439333                   zirconium oxide  282200      29
# 439334                   zirconium oxide  282560      22
# 439335                   zirconium oxide  710490      19
# 439374                 zirconium sulfate  283329       7
# 439375                 zirconium sulfate  284290      39
# 439377                zirconium sulphate  283329       3
# 439378                zirconium sulphate  284190      23
# 439412                            zongzi  190220       8
# 439413                            zongzi  190490      23
# 439416                    zoom binocular  900510       9
# 439417                    zoom binocular  900580       3
#
# [64979 rows x 3 columns]

# %%
# Search contain specific string
df2[df2.name.str.contains("[^a-z ()-0-9#+]", na=False, regex=True)]
# Out:
#                                                      name    code  counts
# 0                              #422 maleic modified resin  390750       7
# 1                       %long persistence luminous powder  320650      48
# 2                                       %steel angled bar  722240      15
# 3                                 'sun' photographic lamp  940540       6
# 6       (+ or -)-1-c2-(amido)-1-(4-anisole group) ethy...  294200       1
# 7                         (2-chlormoethyl cyanide) aether  290949      21
# 8       (380cs coil spring) modified anti-explosion pl...  870893       3
# 18                            (r)- (+)-1,1'-bi-2-naphthol  294200      12
# 20      (r)-6,7-dihydroxyl geraniol benzene ammonia me...  294200      11
# 23                         (s)4-bromo-3-hydroxy butanoate  294200       3
# 24                    (s,s)-2,8-diazabicyclo[4,3,0]nonane  294200       2
# 26                                (sodium edetate)edta4na  292121       7
# 28      (z)-2-(2-tert-butoxycarbonylprop-2-oxyimino)-2...  300490      13
# 29      (z)-2-hydroxyimino-2-(2-aminothiazol-4-y)aceti...  300490       5
# 30      (z)-2-methoxyimino-2-(a-aminothiazol-4-yl)acet...  300490       3
# 46                           0.05 grade digital manometer  902620       1
# 47                      0.05% cockroach insecticide chalk  380891      11
# 48                            0.1 grade digital manometer  902620       1
# 49       0.1hz ultra low frequency high-voltage generator  854370       6
# 50                        0.25 ....25 grade vernier gauge  902620       1
# 51                                0.4 grade vernier gauge  902620       2
# 52      0.9% sodium ...z)-2-hydroxyimino-2-(2-aminothi...  300490       2
# 53                         0.9% sodium chloride injection  300490       6
# 56                                 01 field sleeping suit  940490       6
# 58                    1 belt 16 type ultrasound flowmeter  902610       5
# 59                               1 channel telecontroller  854370       9
# 60      1 channel two-way data video frequency optical...  851762      18
# 61                          1 gang 1 way switch with neon  853650       2
# 62                                          1 inch caster  830220      18
# 63                   1 key ordinary remote control switch  853650       2
# ...                                                   ...     ...     ...
# 440338                                         you'anling  230990       4
# 440345                                          youjin 60  230990       4
# 440377          youngster's aluminium alloy tennis racket  950659       6
# 440422                  yuanwei machine's knitting needle  844859       3
# 440549                                 z4 series dc motor  850140       3
# 440561                                zayou 719 cole seed  120590      18
# 440584        zeng'an type three-phase asynchronous motor  850151      12
# 440647                             zhengdan 958 corn seed  100510       3
# 440703            zhongwei 0.6m offset dish type antennae  852910       5
# 440704         zhongwei 0.6m offset dish type antennae...  852910       1
# 440705                            zhongwei 0.6m offset...  852910       2
# 440715                                      zhuangkesu 44  230990       6
# 440748                                 zhuyeqing no.1 tea  902109      13
# 440749                                  zhuyeqing no.1...  902109       1
# 440750                                 zhuyeqing no.2 tea  902109      13
# 440751                                 zhuyeqing no.3 tea  902109      13
# 440920                     zinc alloy inner & outer tooth  731819      46
# 441232  zinc-5%aluminium-rare earth alloy cladded stee...  731210       2
# 441472  zirconium material 702 metal spirally wound ga...  848410      47
# 441605  ㄗbibcock motion mode medium typeㄘautomatic kni...  846599       2
# 441606                                     万 shaped clamp  830810       2
# 441607                         不可失refrigerator compressor  841430       2
# 441608                           旭 ruller magnetic bridge  901790       8
# 441609                                              汍-pla  292241      43
# 441610                                               烟果槟榔  200600      21
# 441611                                        甩 type belt  580620      17
# 441612                                        甩 type belt  580632       1
# 441613                                              磁座钻孔机  846721       5
# 441614                                              车载吸尘器  850860       1
# 441615    （residual current）zero sequence mutual inductor  850450       6
#
# [11049 rows x 3 columns]

# %%
# Search contain specific string
df2[df2.name.str.contains("[.]{3}|[#]+", na=False, regex=True)]
# Out:
#                                                      name    code  counts
# 0                              #422 maleic modified resin  390750       7
# 50                        0.25 ....25 grade vernier gauge  902620       1
# 52      0.9% sodium ...z)-2-hydroxyimino-2-(2-aminothi...  300490       2
# 55                                000# lubricating grease  271019      18
# 135         1,4-dioxaspiro[4.5...[1, 2-a]-pyrimidin-4-one  294200       9
# 136                          1,4-dioxaspiro[4.5]...-4-one  294200       1
# 137     1,4-dioxaspiro[4.5]...-pyrido[1,2-a]pyrimidin-...  294200       1
# 216                   1-st.2-nd sleeve and ...tin bushing  848390       1
# 218             1-st.2-nd sleeve and hub... flywheel case  848390       1
# 219        1-st.2-nd sleeve and hub...foreign trade shaft  848390       1
# 237     1.5 s key chain digital photo frame... indoor ...  854370       1
# 238                          1.5 s key chain... appliance  854370       1
# 252                                        1.61 ... sheet  900150      24
# 253                   1.61 film waterproof ... resin lens  900150       1
# 254     1.61 film waterproof anti-...no-reflecting fil...  900150       1
# 255     1.61 film waterproof anti-scraping anti-irradi...  900150       1
# 257     1.61 super thin film waterproof anti-scraping ...  900150       1
# 258              1.61 ultrathin...  adolescent resin lens  900150       1
# 261                         1.9 m door ...  iron template  730840       1
# 262               1.9 m door ...disc type vertical member  730840       4
# 263                     1.9 m door ...machine steel mould  730840       1
# 264                    1.9 m door type ... angle template  730840       1
# 306         10% glucose 0.9% sodium chloride ... ointment  300490       1
# 308                          10% glucose 0.9... injection  300490       3
# 326     10.2 inches multifunctional digital photo... m...  854370       4
# 868                     2#_ rock emulsification detonator  360200      60
# 869             2#_ rock powder ammonium ladder detonator  360200      62
# 1297                                     2.2-dibromo-3...  294200       1
# 1302                                              2.4-...  294200       2
# 1303                                2.4-... aniline black  292142       1
# ...                                                   ...     ...     ...
# 415474                                           u.s. ...  847290       1
# 415475                                    u.s. dollar ...  847290       8
# 415476  u.s. dollar ...ultra-thin intelligent currency...  847290       1
# 415478                                     u.s. dollar...  847290       1
# 415480                 u.s. standard screw thread ring...  901730       1
# 415481                                             u.s...  847290       1
# 415482                                  u.v. spraying ...  851770       3
# 415484                           u.v. spraying product...  851770       7
# 418259                             usb 2.0 high-speed ...  847330       1
# 418260            usb 2.0 high-speed mobile hard disk ...  847330       1
# 418262                              usb 2.0 high-speed...  847330       1
# 418263                                    usb 2.0 high...  847330       1
# 418581                                       usb2.0 cd...  847170       1
# 418584                                          usb3.0...  854449       1
# 418594      used in the agm partition board.glass ball...  701810       1
# 418595           used in the agm partition board.glass...  701810       1
# 418986                               v.35 fiber optic ...  851762       2
# 418988                                            v.35...  851762       1
# 420254                                           var. ...  602909       2
# 431450                                 white oil no. 5...  271019       2
# 434771                  with injection valve model i.v...  901832       1
# 439082                                xianfeng 4# capsule  300420      26
# 439261                                 xiongfeng no.1 ...  401490       8
# 439262               xiongfeng no.1 antibiotic rubber ...  401490       2
# 439264  xiongfeng no.1 antibiotic rubber bottle stoppe...  401490       1
# 439265                       xiongfeng no.1 antibiotic...  401490       2
# 439372                                   xuewang no.1 ...  110100      16
# 440704         zhongwei 0.6m offset dish type antennae...  852910       1
# 440705                            zhongwei 0.6m offset...  852910       2
# 440749                                  zhuyeqing no.1...  902109       1
#
# [416 rows x 3 columns]

# %%
# Select rows by index
df2.iloc[2:10]
# Out:
#                                                 name    code  counts
# 2                                  %steel angled bar  722240      15
# 3                            'sun' photographic lamp  940540       6
# 4              ( massage ) antiskid mat for bath use  401691      30
# 5                                    ( tower ) crane  842620       5
# 6  (+ or -)-1-c2-(amido)-1-(4-anisole group) ethy...  294200       1
# 7                    (2-chlormoethyl cyanide) aether  290949      21
# 8  (380cs coil spring) modified anti-explosion pl...  870893       3
# 9  (bops) plastic positive air-pressure thermal f...  847740       1

# %%
df2.name.str.replace("[^a-zA-Z ]", " ")
# Out:
# 0                                     maleic modified resin
# 1                          long persistence luminous powder
# 2                                          steel angled bar
# 3                                    sun  photographic lamp
# 4                       massage   antiskid mat for bath use
# 5                                             tower   crane
# 6            or      c   amido       anisole group  ethy...
# 7                              chlormoethyl cyanide  aether
# 8             cs coil spring  modified anti explosion pl...
# 9          bops  plastic positive air pressure thermal f...
# 10               export type  fetus  multiparameter monitor
# 11            high resistant  magnetic stripe reader writer
# 12                    industrial grade  sodium fluosilicate
# 13                          industrial grade  sulfuric acid
# 14         low temperature  steady state damp heat test box
# 15                                           p  anisic acid
# 16         phase compunded self excitation  three phase ...
# 17                        pressure  tensile strength tester
# 18                               r            bi   naphthol
# 19           r      n methylamine base phenylpropyl alcohol
# 20         r      dihydroxyl geraniol benzene ammonia me...
# 21                                         r  tert leucinol
# 22                                          r r  formoterol
# 23                            s   bromo   hydroxy butanoate
# 24                       s s      diazabicyclo       nonane
# 25                                   seawater  pearl powder
# 26                                   sodium edetate edta na
# 27                uv ultraviolet solidified coating varnish
# 28         z       tert butoxycarbonylprop   oxyimino   ...
# 29         z    hydroxyimino      aminothiazol   y aceti...
#                                 ...
# 441586                                        zudai chicken
# 441587                       zudai luoman brown egg chicken
# 441588                                        zudai poulard
# 441589                                zui xiao xie crablat
# 441590                                       zuiluohan wine
# 441591                                         zuiqianzhang
# 441592                             zuixian wenchang chicken
# 441593                                   zuixiang green tea
# 441594                                       zujiao machine
# 441595                                    zulong snake wine
# 441596                                   zulong techun wine
# 441597                           zun type radio alarm clock
# 441598                                 zuocan partner honey
# 441599                                           zuoji flax
# 441600                               zuozema polyester silk
# 441601                       zwitterion type polyacrylamide
# 441602                               zyme extraction enzyme
# 441603                                               zymine
# 441604                    zzl series winding vacuum coaters
# 441605     bibcock motion mode medium type automatic kni...
# 441606                                         shaped clamp
# 441607                              refrigerator compressor
# 441608                               ruller magnetic bridge
# 441609                                                  pla
# 441610
# 441611                                            type belt
# 441612                                            type belt
# 441613
# 441614
# 441615       residual current zero sequence mutual inductor
# Name: name, Length: 441616, dtype: object
